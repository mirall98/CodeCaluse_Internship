# %% [markdown]
# ## Author: Miral Patel

# %% [markdown]
# ## Code Clause Internship February 2024

# %% [markdown]
# ## Domain: Data Science

# %% [markdown]
# ## Project Title - Heart Disease Risk Assessment

# %% [markdown]
# ### Importing Necessary Libraries

# %%
pip install pgmpy
# Out:
# Requirement already satisfied: pgmpy in c:\users\miral\anaconda3\lib\site-packages (0.1.24)
# Requirement already satisfied: networkx in c:\users\miral\anaconda3\lib\site-packages (from pgmpy) (3.1)
# Requirement already satisfied: numpy in c:\users\miral\anaconda3\lib\site-packages (from pgmpy) (1.24.3)
# Requirement already satisfied: scipy in c:\users\miral\anaconda3\lib\site-packages (from pgmpy) (1.11.1)
# Requirement already satisfied: scikit-learn in c:\users\miral\anaconda3\lib\site-packages (from pgmpy) (1.4.0)
# Requirement already satisfied: pandas in c:\users\miral\anaconda3\lib\site-packages (from pgmpy) (2.0.3)
# Requirement already satisfied: pyparsing in c:\users\miral\anaconda3\lib\site-packages (from pgmpy) (3.0.9)
# Requirement already satisfied: torch in c:\users\miral\anaconda3\lib\site-packages (from pgmpy) (2.2.1)
# Requirement already satisfied: statsmodels in c:\users\miral\anaconda3\lib\site-packages (from pgmpy) (0.14.0)
# Requirement already satisfied: tqdm in c:\users\miral\anaconda3\lib\site-packages (from pgmpy) (4.65.0)
# Requirement already satisfied: joblib in c:\users\miral\anaconda3\lib\site-packages (from pgmpy) (1.2.0)
# Requirement already satisfied: opt-einsum in c:\users\miral\anaconda3\lib\site-packages (from pgmpy) (3.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\miral\anaconda3\lib\site-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\miral\anaconda3\lib\site-packages (from pandas->pgmpy) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\miral\anaconda3\lib\site-packages (from pandas->pgmpy) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\miral\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\miral\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\miral\anaconda3\lib\site-packages (from statsmodels->pgmpy) (23.1)
# Requirement already satisfied: filelock in c:\users\miral\anaconda3\lib\site-packages (from torch->pgmpy) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\miral\anaconda3\lib\site-packages (from torch->pgmpy) (4.9.0)
# Requirement already satisfied: sympy in c:\users\miral\anaconda3\lib\site-packages (from torch->pgmpy) (1.11.1)
# Requirement already satisfied: jinja2 in c:\users\miral\anaconda3\lib\site-packages (from torch->pgmpy) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\miral\anaconda3\lib\site-packages (from torch->pgmpy) (2023.4.0)
# Requirement already satisfied: colorama in c:\users\miral\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: six in c:\users\miral\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels->pgmpy) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\miral\anaconda3\lib\site-packages (from jinja2->torch->pgmpy) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\miral\anaconda3\lib\site-packages (from sympy->torch->pgmpy) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns #for plotting
from sklearn.ensemble import RandomForestClassifier #for the model
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz #plot tree
from sklearn.metrics import roc_curve, auc #for model evaluation
from sklearn.metrics import classification_report #for model evaluation
from sklearn.metrics import confusion_matrix #for model evaluation
from sklearn.model_selection import train_test_split #for data splitting
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from pgmpy.models import BayesianModel   
from pgmpy.inference import VariableElimination
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import cross_val_score
# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

from scipy.stats import zscore
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# ### Importing Dataset

# %%
data_df2=pd.read_csv('heart.csv')

# %%
data_df2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
len(data_df2)
# Out:
# 303

# %%
data_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data_df2['sex'].value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
data_df2['thal'].value_counts()
# Out:
# thal
# 2    166
# 3    117
# 1     18
# 0      2
# Name: count, dtype: int64

# %%
data_df2['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
data_df2['slope'].value_counts()
# Out:
# slope
# 2    142
# 1    140
# 0     21
# Name: count, dtype: int64

# %%
data_df2['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# ### Checking If There Are Any Outliers

# %%
sns.boxplot(data_df2['age'])
# Out:
# <Axes: >

# %%
sns.boxplot(data_df2['trestbps'])
# Out:
# <Axes: >

# %%
sns.boxplot(data_df2['chol'])
# Out:
# <Axes: >

# %%
sns.boxplot(data_df2['thalach'])
# Out:
# <Axes: >

# %%
sns.boxplot(data_df2['oldpeak'])
# Out:
# <Axes: >

# %% [markdown]
# ### Making Changes For Dealing With The Outlier

# %%
# #dealing with outlier
# median_trestbps = float(data_df2['trestbps'].median())
# data_df2["trestbps"] = data_df2["trestbps"].mask(data_df2["trestbps"] >170, median_trestbps)

# median_chol = float(data_df2['chol'].median())
# data_df2["chol"] = data_df2["chol"].mask(data_df2["chol"] >370, median_chol)

# median_oldpeak = float(data_df2['oldpeak'].median())
# data_df2["oldpeak"] = data_df2["oldpeak"].mask(data_df2["oldpeak"] >4, median_oldpeak)

# median_thalach = float(data_df2['thalach'].median())
# data_df2["thalach"] = data_df2["thalach"].mask(data_df2["thalach"] <90, median_thalach)

# %% [markdown]
# ### Using Z Score To Remove Outliers

# %%
z_scores = zscore(data_df2)
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
data_df2 = data_df2[filtered_entries]

# %% [markdown]
# ### By Using Boxplot

# %%
#plot oldpeak feature after replace outliers
sns.boxplot(data_df2['trestbps'])
# Out:
# <Axes: >

# %%
data_df3=data_df2.copy(deep=True)   #To make a copy of dataframe without changing original

# %% [markdown]
# ### Changing The Values Into The Categorical Variables

# %%
data_df3['sex'][data_df3['sex'] == 0] = 'female'
data_df3['sex'][data_df3['sex'] == 1] = 'male'


data_df3['cp'][data_df3['cp'] == 0] = 'typical angina'
data_df3['cp'][data_df3['cp'] == 1] = 'atypical angina'
data_df3['cp'][data_df3['cp'] == 2] = 'non-anginal pain'
data_df3['cp'][data_df3['cp'] == 3] = 'asymptomatic'

data_df3['fbs'][data_df3['fbs'] == 0] = 'lower than 120mg/ml'
data_df3['fbs'][data_df3['fbs'] == 1] = 'greater than 120mg/ml'

data_df3['restecg'][data_df3['restecg'] == 0] = 'normal'
data_df3['restecg'][data_df3['restecg'] == 1] = 'ST-T wave abnormality'
data_df3['restecg'][data_df3['restecg'] == 2] = 'left ventricular hypertrophy'

data_df3['exang'][data_df3['exang'] == 0] = 'no'
data_df3['exang'][data_df3['exang'] == 1] = 'yes'


data_df3['slope'][data_df3['slope'] == 1] = 'upsloping'
data_df3['slope'][data_df3['slope'] == 2] = 'flat'
data_df3['slope'][data_df3['slope'] == 3] = 'downsloping'


data_df3['thal'][data_df3['thal'] == 1] = 'normal'
data_df3['thal'][data_df3['thal'] == 2] = 'fixed defect'
data_df3['thal'][data_df3['thal'] == 3] = 'reversable defect'
# Out:
# C:\Users\miral\AppData\Local\Temp\ipykernel_23508\1620527463.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df3['sex'][data_df3['sex'] == 0] = 'female'
# C:\Users\miral\AppData\Local\Temp\ipykernel_23508\1620527463.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df3['cp'][data_df3['cp'] == 0] = 'typical angina'
# C:\Users\miral\AppData\Local\Temp\ipykernel_23508\1620527463.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df3['fbs'][data_df3['fbs'] == 0] = 'lower than 120mg/ml'
# C:\Users\miral\AppData\Local\Temp\ipykernel_23508\1620527463.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df3['restecg'][data_df3['restecg'] == 0] = 'normal'
# C:\Users\miral\AppData\Local\Temp\ipykernel_23508\1620527463.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df3['exang'][data_df3['exang'] == 0] = 'no'
# C:\Users\miral\AppData\Local\Temp\ipykernel_23508\1620527463.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df3['slope'][data_df3['slope'] == 1] = 'upsloping'
# C:\Users\miral\AppData\Local\Temp\ipykernel_23508\1620527463.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df3['thal'][data_df3['thal'] == 1] = 'normal'

# %%
data_df3.head()
# Out:
#    age     sex                cp  trestbps  chol                    fbs  \
# 0   63    male      asymptomatic       145   233  greater than 120mg/ml
# 1   37    male  non-anginal pain       130   250    lower than 120mg/ml
# 2   41  female   atypical angina       130   204    lower than 120mg/ml
# 3   56    male   atypical angina       120   236    lower than 120mg/ml
# 4   57  female    typical angina       120   354    lower than 120mg/ml
#
#                  restecg  thalach exang  oldpeak slope  ca          thal  \
# 0                 normal      150    no      2.3     0   0        normal
# 1  ST-T wave abnormality      187    no      3.5     0   0  fixed defect
# 2                 normal      172    no      1.4  flat   0  fixed defect
# 3  ST-T wave abnormality      178    no      0.8  flat   0  fixed defect
# 4  ST-T wave abnormality      163   yes      0.6  flat   0  fixed defect
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ### Data Visualization

# %%
def bar_chart(feature):
    presence_0=data_df3[data_df3['target']==0][feature].value_counts()
    presence_1=data_df3[data_df3['target']==1][feature].value_counts()

    df_target=pd.DataFrame([presence_0,presence_1])
    df_target.index=['No_presence','presence']
    df_target.plot(kind='bar',stacked=True,figsize=(10,5))

# %% [markdown]
# ### By Using Bar Chart

# %%
bar_chart('sex')

# %%
bar_chart('cp')

# %%
bar_chart('fbs')

# %%
bar_chart('restecg')

# %%
bar_chart('thal')

# %%
bar_chart('slope')

# %%
data_df3 = pd.get_dummies(data_df3, drop_first=True)

# %%
data_df3.head()
# Out:
#    age  trestbps  chol  thalach  oldpeak  ca  target  sex_male  \
# 0   63       145   233      150      2.3   0       1      True
# 1   37       130   250      187      3.5   0       1      True
# 2   41       130   204      172      1.4   0       1     False
# 3   56       120   236      178      0.8   0       1      True
# 4   57       120   354      163      0.6   0       1     False
#
#    cp_atypical angina  cp_non-anginal pain  cp_typical angina  \
# 0               False                False              False
# 1               False                 True              False
# 2                True                False              False
# 3                True                False              False
# 4               False                False               True
#
#    fbs_lower than 120mg/ml  restecg_left ventricular hypertrophy  \
# 0                    False                                 False
# 1                     True                                 False
# 2                     True                                 False
# 3                     True                                 False
# 4                     True                                 False
#
#    restecg_normal  exang_yes  slope_flat  slope_upsloping  thal_normal  \
# 0            True      False       False            False         True
# 1           False      False       False            False        False
# 2            True      False        True            False        False
# 3           False      False        True            False        False
# 4           False       True        True            False        False
#
#    thal_reversable defect
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False

# %% [markdown]
# ### Splitting The Data Into Test And Train

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(data_df3.drop(columns='target'), data_df3['target'], test_size=0.2, random_state=10)

# %% [markdown]
# ### Data Scaling

# %%
sd_X=StandardScaler()  #Standardization
X_train_sc1 = sd_X.fit_transform(X_train1)
X_test_sc1 = sd_X.transform(X_test1)


# sc_X = MinMaxScaler()
# X_train_sc1 = sc_X.fit_transform(X_train1)
# X_test_sc1 = sc_X.transform(X_test1)

# %% [markdown]
# ### Making More Tuning By Using Other Algorithms

# %%
logi_clf = LogisticRegression(solver='lbfgs', max_iter=500)
logi_parm = {"C": [0.1, 0.5, 1, 5, 10, 50],
            'random_state': [0,1,2,3,4,5]}

svm_clf = SVC(probability=True)
svm_parm = {'kernel': ['rbf', 'poly'], 
            'C': [1, 5, 50, 100, 500, 1000,1500,2000], 
            'degree': [3, 5, 7], 
       'gamma':[0.01,0.04,.1,0.2,.3,.4,.6],
           'random_state': [0,1,2,3,4,5]}

dt_clf = DecisionTreeClassifier()
dt_parm = {'criterion':['gini', 'entropy'],
          'random_state': [0,1,2,3,4,5]}

knn_clf = KNeighborsClassifier()
knn_parm = {'n_neighbors':[5, 10, 15, 20], 
            'weights':['uniform', 'distance'], 
            'p': [1,2]}

gnb_clf = GaussianNB()
gnb_parm = {'priors':['None']}

clfs = [logi_clf, svm_clf, dt_clf, knn_clf]
params = [logi_parm, svm_parm, dt_parm, knn_parm] 
clf_names = ['logistic', 'SVM', 'DT', 'KNN', 'GNB']

# %%
clfs_opt = []
clfs_best_scores = []
clfs_best_param = []
for clf_, param in zip(clfs, params):
    clf = RandomizedSearchCV(clf_, param, cv=5)
    clf.fit(X_train_sc1, y_train1)
    clfs_opt.append(clf.best_estimator_)
    clfs_best_scores.append(clf.best_score_)
    clfs_best_param.append(clf.best_params_)

# %% [markdown]
# ### Visualizing And Print The Best Model Score

# %%
max(clfs_best_scores)
# Out:
# 0.8514009661835749

# %%
arg = np.argmax(clfs_best_scores)
clfs_best_param[arg]
clf = clfs_opt[arg]

# %%
clf
# Out:
# LogisticRegression(C=0.1, max_iter=500, random_state=2)

# %%
pred = clf.predict(X_test_sc1)

# %%
y_test=pd.DataFrame(y_test1)
pred=pd.DataFrame(pred)
pred=np.array(pred)
y_test=np.array(y_test)
pred=np.concatenate(pred)
y_test=np.concatenate(y_test)

# %%
data1 = {'y_Actual':    y_test,
        'y_Predicted': pred}

# %%
df1 = pd.DataFrame(data1, columns=['y_Actual','y_Predicted'])

# %% [markdown]
# ### By Using Confusion Matrix

# %%
confusion_matrix = pd.crosstab(df1['y_Actual'], df1['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])
print (confusion_matrix)
# Out:
# Predicted   0   1
# Actual
# 0          22   9
# 1           0  27

# %% [markdown]
# ### Making Use Of Random Forest Classifier

# %%
model2 = RandomForestClassifier(max_depth=5)
model2.fit(X_train_sc1, y_train1)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
y_predict2 = model2.predict(X_test_sc1)

# %%
y_predict2=np.array(y_predict2)
y_test1=np.array(y_test1)

# %%
data3 = {'y_Actual':    y_test1,
        'y_Predicted': y_predict2}

# %%
df3 = pd.DataFrame(data3, columns=['y_Actual','y_Predicted'])

# %%
confusion_matrix = pd.crosstab(df3['y_Actual'], df3['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])
print (confusion_matrix)
# Out:
# Predicted   0   1
# Actual
# 0          22   9
# 1           0  27

# %%
accuracy_score(y_test1,y_predict2)
# Out:
# 0.8448275862068966

# %% [markdown]
# So Our Accuracy Score Is 0.8448275862068966

# %% [markdown]
# ### By Using Gradient Boosting Classifier

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

# %%
p_test = {'learning_rate': [0.15, 0.1, 0.05, 0.01, 0.005, 0.001],
          'n_estimators': [100, 250, 500, 750, 1000, 1250, 1500, 1750]}

tuning = GridSearchCV(estimator=GradientBoostingClassifier(max_depth=4, min_samples_split=2, min_samples_leaf=1, subsample=1, max_features='sqrt', random_state=10), 
                      param_grid=p_test, scoring='accuracy', n_jobs=4, cv=5)
tuning.fit(X_train_sc1, y_train1)
# Out:
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(max_depth=4,
#                                                   max_features='sqrt',
#                                                   random_state=10,
#                                                   subsample=1),
#              n_jobs=4,
#              param_grid={'learning_rate': [0.15, 0.1, 0.05, 0.01, 0.005, 0.001],
#                          'n_estimators': [100, 250, 500, 750, 1000, 1250, 1500,
#                                           1750]},
#              scoring='accuracy')

# %%
for i in ['mean_test_score', 'std_test_score', 'param_n_estimators']:
        print(i," : ",tuning.cv_results_[i])
# Out:
# mean_test_score  :  [0.847343   0.84289855 0.82985507 0.82985507 0.82985507 0.82985507
#  0.82985507 0.82985507 0.82560386 0.81681159 0.81246377 0.80811594
#  0.80811594 0.80811594 0.80811594 0.80811594 0.83439614 0.82995169
#  0.82985507 0.8210628  0.82985507 0.82550725 0.8210628  0.8210628
#  0.84309179 0.85198068 0.84309179 0.82995169 0.82560386 0.82995169
#  0.82995169 0.82125604 0.82115942 0.85188406 0.86057971 0.85188406
#  0.84753623 0.83439614 0.83874396 0.82995169 0.57207729 0.73797101
#  0.82995169 0.83864734 0.83874396 0.84753623 0.84753623 0.85188406]
# std_test_score  :  [0.04915681 0.04180952 0.03680817 0.03680817 0.03680817 0.03680817
#  0.03680817 0.03680817 0.05941047 0.05548738 0.05192048 0.06305664
#  0.06305664 0.06305664 0.06305664 0.06305664 0.05010982 0.06314658
#  0.05175029 0.05364416 0.05860236 0.05951989 0.06481472 0.06481472
#  0.04979868 0.07800375 0.06011758 0.05684494 0.05779765 0.05684494
#  0.05684494 0.05333736 0.04583561 0.06894896 0.06206148 0.06322828
#  0.05951142 0.05196182 0.05551093 0.05684494 0.00888889 0.04962705
#  0.0366195  0.0397018  0.05378129 0.05624533 0.05624533 0.06016431]
# param_n_estimators  :  [100 250 500 750 1000 1250 1500 1750 100 250 500 750 1000 1250 1500 1750
#  100 250 500 750 1000 1250 1500 1750 100 250 500 750 1000 1250 1500 1750
#  100 250 500 750 1000 1250 1500 1750 100 250 500 750 1000 1250 1500 1750]

# %%
GB=GradientBoostingClassifier(max_depth=4, min_samples_split=2, min_samples_leaf=1, subsample=1,max_features='sqrt', random_state=10, 
          learning_rate= 0.01, n_estimators= 1750)

# %%
GB.fit(X_train_sc1, y_train1)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, max_depth=4, max_features='sqrt',
#                            n_estimators=1750, random_state=10, subsample=1)

# %%
y_predict_GB = GB.predict(X_test_sc1)

# %%
y_predict_GB=np.array(y_predict_GB)
y_test1=np.array(y_test1)

# %%
data4 = {'y_Actual':    y_test1,
        'y_Predicted': y_predict_GB}

# %%
df4 = pd.DataFrame(data4, columns=['y_Actual','y_Predicted'])

# %% [markdown]
# ### By Using Confusion Matrix

# %%
confusion_matrix = pd.crosstab(df3['y_Actual'], df4['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])
print (confusion_matrix)
# Out:
# Predicted   0   1
# Actual
# 0          23   8
# 1           0  27

# %%
accuracy_score(y_test1,y_predict_GB)
# Out:
# 0.8620689655172413

# %% [markdown]
# So The Accuracy Score Is 0.8620689655172413

# %% [markdown]
# ### By Applying Bayesian Network

# %%
data_df2.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
model3=BayesianModel([('age','trestbps'),('age','sex'),('trestbps','slope'),('slope','target')])
# Out:
# WARNING:pgmpy:BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.

# %%
model3.fit(data_df2)

# %%
inference=VariableElimination(model3)

# %%
query=inference.query(variables=['target'],evidence={'age':68,'sex':1,'trestbps':144,'slope':1})
# Out:
# WARNING:pgmpy:BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
# WARNING:pgmpy:BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.

# %%
print(query) #depend on how we construct the network
# Out:
# +-----------+---------------+
# | target    |   phi(target) |
# +===========+===============+
# | target(0) |        0.6466 |
# +-----------+---------------+
# | target(1) |        0.3534 |
# +-----------+---------------+

# %% [markdown]
# ## Task Completed By Miral Patel

# %% [markdown]
# ## Thankyou
